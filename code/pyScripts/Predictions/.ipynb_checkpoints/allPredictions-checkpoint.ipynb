# %%
#Main analysis
import masterClass
#Train one task one sub test same task other sub
masterClass.classifyDS('SVM')
#All vs rest (binary) Train one sub test other sub
masterClass.classifyAll('SVM')
#All task and rest multiclass
masterClass.multiclassAll('SVM')
#All vs rest (binary) at network level
masterClass.classifyIndNet('SVM')

# %%
#Random feature selection
import masterClass_rdmNet 
#Single task
masterClass_rdmNet.rdmNet_DS() 
#All vs rest (binary)
masterClass_rdmNet.rdmNet_classifyAll()
# Out:
# Finished with 0 in iteration 100
# Finished with 1 in iteration 100
# Finished with 2 in iteration 100
# Finished with 3 in iteration 100
# Finished with 4 in iteration 100
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-381b06cba0d7> in <module>
#       2 import masterClass_rdmNet
#       3 #Single task
# ----> 4 masterClass_rdmNet.rdmNet_DS()
#       5 #All vs rest (binary)
#       6 masterClass_rdmNet.rdmNet_classifyAll()
#
# ~/Desktop/Porteretal_taskprediction/code/pyScripts/Predictions/masterClass_rdmNet.py in rdmNet_DS()
#      32             #generate a new index
#      33             idx=np.random.randint(55278, size=(number))
# ---> 34             DS=DSmodel(idx)
#      35             DS['feature']=number
#      36             DS_df=pd.concat([DS_df,DS])
#
# ~/Desktop/Porteretal_taskprediction/code/pyScripts/Predictions/masterClass_rdmNet.py in DSmodel(idx)
#     261             taskFC=reshape.randFeats(dataDir+t+'/'+train_sub[0]+'_parcel_corrmat.mat',idx)
#     262             restFC=reshape.randFeats(dataDir+'rest/'+train_sub[0]+'_parcel_corrmat.mat',idx) #keep tasks seperated in order to collect the right amount of days
# --> 263             test_taskFC,test_restFC=AllSubFiles_DS(test_sub,t,idx)
#     264             same_sub, diff_sub=single_task_folds(clf, taskFC,restFC, test_taskFC,test_restFC)
#     265             tmp['train']=train_sub
#
# ~/Desktop/Porteretal_taskprediction/code/pyScripts/Predictions/masterClass_rdmNet.py in AllSubFiles_DS(test_sub, task, idx)
#     287
#     288     c_taskFC=reshape.randFeats(dataDir+task+'/'+test_sub[2]+'_parcel_corrmat.mat',idx)
# --> 289     c_restFC=reshape.randFeats(dataDir+'rest/'+test_sub[2]+'_parcel_corrmat.mat',idx)
#     290
#     291     d_taskFC=reshape.randFeats(dataDir+task+'/'+test_sub[3]+'_parcel_corrmat.mat',idx)
#
# ~/Desktop/Porteretal_taskprediction/code/pyScripts/Predictions/reshape.py in randFeats(df, idx)
#     395     featDS : Array of task or rest with random features selected
#     396     """
# --> 397     data=matFiles(df)
#     398     feat=idx.shape[0]
#     399     nsess=data.shape[0]
#
# ~/Desktop/Porteretal_taskprediction/code/pyScripts/Predictions/reshape.py in matFiles(df)
#      27     nrois=333
#      28     #Load FC file
# ---> 29     fileFC=scipy.io.loadmat(df)
#      30
#      31     #Convert to numpy array
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio.py in loadmat(file_name, mdict, appendmat, **kwargs)
#     222     with _open_file_context(file_name, appendmat) as f:
#     223         MR, _ = mat_reader_factory(f, **kwargs)
# --> 224         matfile_dict = MR.get_variables(variable_names)
#     225
#     226     if mdict is not None:
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in get_variables(self, variable_names)
#     331                 continue
#     332             try:
# --> 333                 res = self.read_var_array(hdr, process)
#     334             except MatReadError as err:
#     335                 warnings.warn(
#
# /opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio5.py in read_var_array(self, header, process)
#     291            `process`.
#     292         '''
# --> 293         return self._matrix_reader.array_from_header(header, process)
#     294
#     295     def get_variables(self, variable_names=None):
#
# KeyboardInterrupt:

# %%
#Blockwise analysis
import block_featSelection
#All vs rest (binary)
block_featSelection.blockNetAll()
#Single task
block_featSelection.blockNetDS()

# %%
#Whole network analysis
import featSelection
#Does both all vs rest and single task
featSelection.runScript()

# %%
#Permutation (labels)
import masterClass_permutation
#Train one task one sub test same task other sub
masterClass_permutation.permut_single_task('Ridge')
#All vs rest (binary) Train one sub test other sub
masterClass_permutation.permutAll_Binary('Ridge')
#All task and rest multiclass
masterClass_permutation.permutMC('Ridge')
#All vs rest (binary) at network level
masterClass_permutation.permutIndNet('Ridge')

# %%
#Permutation (group level)
import permutGroupLevel
permutGroupLevel.perm_btw()
# Out:
# p value for all vs rest (binary) is 0.000999000999000999
# p value for mem task is 0.000999000999000999
# p value for motor task is 0.000999000999000999
# p value for semantic task is 0.000999000999000999
# p value for glass task is 0.000999000999000999
# p value for multiclass is 0.000999000999000999
# p value at network level is 0.000999000999000999

# %%
#Data quantity (sample pairs)
import manDays
manDays.runDays()

# %%
#Groupwise analysis 
import groupwise_approach
#Leave one subject out Single task
#groupwise_approach.groupApp()
#Leave one subject out All vs Rest (binary)
#groupwise_approach.allTask()
# Leave one subject out Single task (use all sessions)
#groupwise_approach.groupApp_LOSO()
#groupwise_approach.classifyDS()
# Use all data possible starting with 2 samples a person to 8 samples a person (some subs only have 8)
#groupwise_approach.increment()
##Multiclass
#groupwise_appraoch.multiclassAll()


#multiclass matched samples train 7 sub * 5 task test 1 sub all sessions and task
#groupwise_approach.multiclassAll_matched()
groupwise_approach.multiclassAll_singleSub()

# %%
#Feature Weights
import featureWeights
#featureWeights.allFolds('MSC06')
#featureWeights.allTasks() done
#featureWeights.allSubs() done
#featureWeights.groupApp() done
#featureWeights.allTask_FW() done

#featureWeights.max_groupwise_LOSO('motor') #done

#featureWeights.groupAve_maxSession() done

# %%
import memClass_press as mC
#mC.classifyDS('Ridge')
mC.classifydiffMem('Ridge')

# %%
sameT
# Out:
# 0.675
