# %%
#Code to help get all csv files into a useable format for making into figures
import pandas as pd
import numpy as np
import sys
import os
thisDir = os.path.expanduser('~/Desktop/MSC_Alexis/analysis/')
#directory for all regular analysis
outDir = thisDir + 'output/results/'
taskList=['semantic','mem','motor','glass']
subList=['MSC01','MSC02','MSC03','MSC04','MSC05','MSC06','MSC07','MSC10']
#all permutations of features
subDir=outDir+'subNetwork'
randDir=outDir+'rdmNetwork'
netList=['unassign','default', 'visual','fp','dan','van','salience','co','sm','sm-lat', 'auditory','pmn','pon']
feature=[14808,10824,8736, 4620,5264,3151, 484, 4060, 2375,316, 564,45,21]
netRoi=dict([('unassign',14808),('default', 10824),('visual',8736),('fp', 4620),('dan',5264),('van',3151),('salience', 484),('co', 4060),('sm', 2375),('sm-lat', 316),('auditory', 564),('pmn',45),('pon',21)])


#Random sampling and feature selection calculate z scores
#subnetworks overlapped with random network sampling

rdmNetSS=pd.read_csv(randDir+'/SS/nullNet_acc.csv')
rdmNetDS=pd.read_csv(randDir+'/DS/nullNet_acc.csv')
rdmNetBS=pd.read_csv(randDir+'/BS/nullNet_acc.csv')
rdmNetCV=pd.read_csv(randDir+'/CV/nullNet_acc.csv')
rdmNetAll=pd.read_csv(randDir+'/ALL/nullNet_acc.csv')


NetSS=pd.read_csv(subDir+'/SS/acc.csv')
NetDS=pd.read_csv(subDir+'/DS/acc.csv')
NetBS=pd.read_csv(subDir+'/BS/acc.csv')
#NetCV=pd.read_csv(subDir+'/CV/acc.csv')
NetAll=pd.read_csv(subDir+'/ALL/acc.csv')

# %%
NetAll
# Out:
#      train  same_sub  diff_sub   network  feature
# 0    MSC01    0.9375  0.592844  unassign    14808
# 1    MSC02    0.9750  0.623971  unassign    14808
# 2    MSC03    0.8750  0.522719  unassign    14808
# 3    MSC04    0.9875  0.568515  unassign    14808
# 4    MSC05    0.9750  0.648301  unassign    14808
# ..     ...       ...       ...       ...      ...
# 99   MSC04    0.8125  0.538462       pon       21
# 100  MSC05    0.6750  0.554204       pon       21
# 101  MSC06    0.7500  0.551429       pon       21
# 102  MSC07    0.5375  0.534526       pon       21
# 103  MSC10    0.6125  0.517352       pon       21
#
# [104 rows x 5 columns]

# %%
SS=NetSS.groupby(['feature','network']).mean()
SS_z=rdmNetSS.groupby(['features','Null_Network']).mean()
SS_z['std']=rdmNetSS.groupby(['features','Null_Network']).std()
SS_z.reset_index(inplace=True)
SS_z.rename(columns={'features':'feature','Null_Network':'network','acc':'mu'},inplace=True)
SS_zscores=SS.merge(SS_z,how='left',on=['network'])
SS_zscores['z_score']=(SS_zscores['acc']-SS_zscores['mu'])/SS_zscores['std']

# %%
BS=NetBS.groupby(['feature','network']).mean()
BS_z=rdmNetBS.groupby(['features','Null_Network']).mean()
BS_z['std']=rdmNetBS.groupby(['features','Null_Network']).std()
BS_z.reset_index(inplace=True)
BS_z.rename(columns={'features':'feature','Null_Network':'network','acc':'mu'},inplace=True)
BS_zscores=BS.merge(BS_z,how='left',on=['network'])
BS_zscores['z_score']=(BS_zscores['acc']-BS_zscores['mu'])/BS_zscores['std']

# %%
CV=NetCV.groupby(['feature','network']).mean()
CV_z=rdmNetCV.groupby(['features','Null_Network']).mean()
CV_z['std']=rdmNetCV.groupby(['features','Null_Network']).std()
CV_z.reset_index(inplace=True)
CV_z.rename(columns={'features':'feature','Null_Network':'network','acc':'mu'},inplace=True)
CV_zscores=CV.merge(CV_z,how='left',on=['network'])
CV_zscores['z_score']=(CV_zscores['acc']-CV_zscores['mu'])/CV_zscores['std']

# %%
DS=NetDS.groupby(['feature','network']).mean()
DS_z=rdmNetDS.groupby(['features','Null_Network']).mean()
DS_z['std']=rdmNetDS.groupby(['features','Null_Network']).std()
DS_z.reset_index(inplace=True)
DS_z.rename(columns={'features':'feature','Null_Network':'network','acc':'mu'},inplace=True)
DS_zscores=DS.merge(DS_z,how='left',on=['network'])
DS_zscores['z_score']=(DS_zscores['acc']-DS_zscores['mu'])/DS_zscores['std']

# %%
All=NetAll.groupby(['feature','network']).mean()
All_z=rdmNetAll.groupby(['features','Null_Network']).mean()
All_std=rdmNetAll.groupby(['features','Null_Network']).std()
#All_z.rename(columns={'cv_acc':'cv_mu','acc':'ds_mu'},inplace=True)
#All_std.rename(columns={'cv_acc':'cv_std','acc':'ds_std'},inplace=True)
All_z=All_z.merge(All_std, on=['features','Null_Network'])
All_z.reset_index(inplace=True)
All_z.rename(columns={'features':'feature','Null_Network':'network'},inplace=True)
All_zscores=All.merge(All_z,how='left',on=['network'])
All_zscores['CV_z_score']=(All_zscores['same_sub']-All_zscores['cv_mu'])/All_zscores['cv_std']
All_zscores['DS_z_score']=(All_zscores['diff_sub']-All_zscores['ds_mu'])/All_zscores['ds_std']

# %%
CV_zscores.to_csv(randDir+'/CV/zscore_all.csv',index=False)
SS_zscores.to_csv(randDir+'/SS/zscore_all.csv',index=False)
DS_zscores.to_csv(randDir+'/DS/zscore_all.csv',index=False)
BS_zscores.to_csv(randDir+'/BS/zscore_all.csv',index=False)
All_zscores.to_csv(randDir+'/ALL/zscore_all.csv',index=False)

# %%
rdmNetCV
# Out:
#         sub      task   acc  features Null_Network
# 0     MSC01  semantic  0.95     14808     unassign
# 1     MSC01     glass  0.90     14808     unassign
# 2     MSC01     motor  1.00     14808     unassign
# 3     MSC01       mem  1.00     14808     unassign
# 4     MSC02  semantic  0.90     14808     unassign
# ...     ...       ...   ...       ...          ...
# 5115  MSC07       mem  1.00      1640   default_co
# 5116  MSC10  semantic  0.80      1640   default_co
# 5117  MSC10     glass  0.80      1640   default_co
# 5118  MSC10     motor  0.95      1640   default_co
# 5119  MSC10       mem  0.95      1640   default_co
#
# [5120 rows x 5 columns]

# %%
CV=NetCV.groupby(['feature','network','task']).mean()
CV_z=rdmNetCV.groupby(['features','Null_Network','task']).mean()
CV_z['std']=rdmNetCV.groupby(['features','Null_Network','task']).std()
CV_z.reset_index(inplace=True)
CV_z.rename(columns={'features':'feature','Null_Network':'network','acc':'mu'},inplace=True)
CV_zscores=CV.merge(CV_z,how='left',on=['network','task'])
CV_zscores['z_score']=(CV_zscores['acc']-CV_zscores['mu'])/CV_zscores['std']

# %%
CV_zscores.to_csv(randDir+'/CV/zscore_splitTask.csv',index=False)

# %%
DS=NetDS.groupby(['task','feature','network']).mean()
DS_z=rdmNetDS.groupby(['task','features','Null_Network']).mean()
DS_z['std']=rdmNetDS.groupby(['task','features','Null_Network']).std()
DS_z.reset_index(inplace=True)
DS_z.rename(columns={'features':'feature','Null_Network':'network','acc':'mu'},inplace=True)
DS_zscores=DS.merge(DS_z,how='left',on=['network','task'])
DS_zscores['z_score']=(DS_zscores['acc']-DS_zscores['mu'])/DS_zscores['std']

# %%
DS_zscores.to_csv(randDir+'/DS/zscore_splitTask.csv',index=False)

# %%
DS_zscores
# Out:
#      network      task       acc  feature        mu       std   z_score
# 0        pon     glass  0.588086       21  0.559356  0.097968  0.293256
# 1        pmn     glass  0.538518       45  0.568895  0.100024 -0.303698
# 2     sm-lat     glass  0.565349      316  0.603458  0.104971 -0.363042
# 3   salience     glass  0.609537      484  0.608184  0.108949  0.012426
# 4   auditory     glass  0.579842      564  0.588811  0.098231 -0.091297
# 5         sm     glass  0.572501     2375  0.589062  0.106567 -0.155404
# 6        van     glass  0.556321     3151  0.587062  0.101139 -0.303944
# 7         co     glass  0.586417     4060  0.584129  0.102972  0.022221
# 8         fp     glass  0.620720     4620  0.586026  0.103965  0.333709
# 9        dan     glass  0.628810     5264  0.581803  0.104111  0.451509
# 10    visual     glass  0.616900     8736  0.577838  0.097048  0.402495
# 11   default     glass  0.641470    10824  0.581230  0.102149  0.589723
# 12  unassign     glass  0.519850    14808  0.581209  0.102630 -0.597875
# 13       pon       mem  0.485536       21  0.582438  0.109619 -0.883989
# 14       pmn       mem  0.550536       45  0.605330  0.116832 -0.469005
# 15    sm-lat       mem  0.604464      316  0.770062  0.131305 -1.261175
# 16  salience       mem  0.700714      484  0.777223  0.132091 -0.579214
# 17  auditory       mem  0.570000      564  0.821348  0.120016 -2.094294
# 18        sm       mem  0.657411     2375  0.870866  0.103444 -2.063481
# 19       van       mem  0.622857     3151  0.868134  0.113014 -2.170324
# 20        co       mem  0.723304     4060  0.879518  0.104978 -1.488070
# 21        fp       mem  0.718482     4620  0.874304  0.106065 -1.469107
# 22       dan       mem  0.712321     5264  0.878804  0.105749 -1.574310
# 23    visual       mem  0.824107     8736  0.887250  0.098967 -0.638022
# 24   default       mem  0.853304    10824  0.883875  0.103760 -0.294635
# 25  unassign       mem  0.729464    14808  0.889384  0.102389 -1.561879
# 26       pon     motor  0.550982       21  0.603759  0.115929 -0.455251
# 27       pmn     motor  0.551429       45  0.635857  0.120971 -0.697922
# 28    sm-lat     motor  0.713929      316  0.729527  0.133838 -0.116546
# 29  salience     motor  0.642679      484  0.749911  0.135579 -0.790920
# 30  auditory     motor  0.607679      564  0.762759  0.138629 -1.118669
# 31        sm     motor  0.754196     2375  0.775946  0.151348 -0.143709
# 32       van     motor  0.619554     3151  0.784938  0.153955 -1.074239
# 33        co     motor  0.771964     4060  0.778080  0.151430 -0.040389
# 34        fp     motor  0.686429     4620  0.781964  0.149519 -0.638956
# 35       dan     motor  0.689732     5264  0.788518  0.151048 -0.654002
# 36    visual     motor  0.772143     8736  0.788438  0.149651 -0.108884
# 37   default     motor  0.789107    10824  0.788357  0.147571  0.005082
# 38  unassign     motor  0.619554    14808  0.792000  0.151550 -1.137883
# 39       pon  semantic  0.635893       21  0.575438  0.115496  0.523440
# 40       pmn  semantic  0.584018       45  0.606277  0.115706 -0.192375
# 41    sm-lat  semantic  0.547857      316  0.652036  0.125825 -0.827963
# 42  salience  semantic  0.677054      484  0.674330  0.129800  0.020980
# 43  auditory  semantic  0.557589      564  0.662170  0.132428 -0.789715
# 44        sm  semantic  0.569821     2375  0.673777  0.143683 -0.723505
# 45       van  semantic  0.671250     3151  0.671063  0.146816  0.001277
# 46        co  semantic  0.640625     4060  0.667277  0.143898 -0.185213
# 47        fp  semantic  0.728125     4620  0.673973  0.145816  0.371371
# 48       dan  semantic  0.755000     5264  0.671946  0.142742  0.581844
# 49    visual  semantic  0.653929     8736  0.671437  0.144845 -0.120881
# 50   default  semantic  0.701071    10824  0.669652  0.144437  0.217532
# 51  unassign  semantic  0.551786    14808  0.672259  0.144734 -0.832378
